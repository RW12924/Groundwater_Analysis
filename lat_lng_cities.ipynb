# %%
cities_map
# Out:
#    _id_x           site_code            msmt_date  wlm_rpe  wlm_gse     gwe  \
# 0      1  320000N1140000W001  2023-11-30T14:59:00   545.92   545.92  122.82
# 1      2  320000N1140000W001  2023-10-26T16:08:00   545.92   545.92  162.42
# 2      3  320000N1140000W001  2023-09-28T00:00:00   545.92   545.92  160.92
# 3      4  320000N1140000W001  2023-08-31T00:00:00   545.92   545.92  168.92
# 4      5  320000N1140000W001  2023-07-27T00:00:00   545.92   545.92  161.72
#
#    gse_gwe wlm_qa_desc  wlm_qa_detail                 wlm_mthd_desc  ...  \
# 0    423.1        Good            NaN  Electric sounder measurement  ...
# 1    383.5        Good            NaN  Electric sounder measurement  ...
# 2    385.0        Good            NaN  Electric sounder measurement  ...
# 3    377.0        Good            NaN  Electric sounder measurement  ...
# 4    384.2        Good            NaN  Electric sounder measurement  ...
#
# ...

# %%
hover_info = ['City', 'Lat', 'Lng', 'Humidity']

# Plot the humidity map with hover information
humidity_map = cities_map.hvplot(
    tiles='EsriImagery',
    size='Humidity',  # Size of points based on 'Humidity' column from our df
    hover_cols=hover_info,  # Columns to display when hovering
    frame_width=800,  # Width of the plot
    frame_height=500,  # Height of the plot
    title='Humidity Distribution Map',  # Title of the plot
)

humidity_map  # Display the plot

# %%
import pandas as pd
from shapely.geometry import Point

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("testdata.csv")

# Display sample data
city_data_df.head(20)
#imported geopandas to help with plotting the map
import geopandas as gpd

# Create a GeoDataFrame to make a map. it automatically uses the lat and lng from dataframe when zipped and using Point to create the geometry "point" objects
city_data_df['geometry'] = list(zip(city_data_df['Lng'], city_data_df['Lat']))
city_data_df['geometry'] = city_data_df['geometry'].apply(Point) #magic
cities_map = gpd.GeoDataFrame(city_data_df)

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
